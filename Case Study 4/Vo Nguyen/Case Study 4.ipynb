# %% [markdown]
# # Case Study 4

# %% [markdown]
# ### Import Packages

# %%
#Basic Packages
import numpy as np
import pandas as pd
from scipy.io.arff import loadarff

#Basic Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# %% [markdown]
# ### Load Data

# %%
test = pd.read_csv('1year.arff',header=None,skiprows=69)

# %%
display(test)
# Out:
#              0        1         2        3        4          5          6   \
# 0       0.20055  0.37951   0.39641   2.0472   32.351    0.38825    0.24976
# 1       0.20912  0.49988   0.47225   1.9447   14.786          0    0.25834
# 2       0.24866  0.69592   0.26713   1.5548  -1.1523          0    0.30906
# 3      0.081483  0.30734   0.45879   2.4928   51.952    0.14988   0.092704
# 4       0.18732  0.61323    0.2296   1.4063  -7.3128    0.18732    0.18732
# ...         ...      ...       ...      ...      ...        ...        ...
# 7022   0.018371   0.4741  -0.13619  0.60839  -18.449   0.018371   0.018371
# 7023  -0.013359  0.58354  -0.02265  0.92896  -42.232  -0.013359  -0.015036
# 7024   0.006338  0.50276   0.43923   1.8736   9.7417   0.006338   0.012022
# 7025  -0.041643   0.8481  -0.12852  0.57485  -121.92          0  -0.036795
# 7026   0.014946  0.94648   0.03211   1.0363  -20.581          0    0.01526
#
# ...

# %%
raw_data = loadarff('1year.arff')
df_data = pd.DataFrame(raw_data[0])
df=df_data

# %%
display(df_data)
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
df_data.describe()
# Out:
#              Attr1        Attr2        Attr3        Attr4         Attr5  \
# count  7024.000000  7024.000000  7024.000000  6997.000000  7.019000e+03
# mean      0.034660     0.560215     0.119969     2.629143 -2.631672e+02
# std       4.565504     5.350084     5.275459    13.257356  3.707460e+04
# min    -256.890000   -72.162000  -440.500000     0.000000 -2.722100e+06
# 25%       0.021182     0.296678     0.026968     1.063100 -4.449800e+01
# 50%       0.075802     0.482960     0.181275     1.502000 -5.373900e+00
# 75%       0.160268     0.680233     0.362548     2.460700  3.777050e+01
# max      94.280000   441.500000     1.000000  1017.800000  9.909000e+05
#
#              Attr6        Attr7        Attr8        Attr9       Attr10  ...  \
# count  7024.000000  7024.000000  7002.000000  7026.000000  7024.000000  ...
# mean      0.059712     0.313876     2.623996     5.552855     1.825832  ...
# std       6.051113     8.353274    18.708327   101.995448    33.836452  ...
# ...

# %%
df_data.dtypes.unique
# Out:
# <bound method Series.unique of Attr1     float64
# Attr2     float64
# Attr3     float64
# Attr4     float64
# Attr5     float64
#            ...
# Attr61    float64
# Attr62    float64
# Attr63    float64
# Attr64    float64
# class      object
# Length: 65, dtype: object>

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Subset data to include only 'Target' and other features
features = df.columns[df.columns != 'class']
subset_data = df[['class'] + list(features)]

# Plot
sns.pairplot(subset_data, x_vars=features, y_vars='class', height=4)
plt.show()

# %% [markdown]
# ## Target Label
# Clean the Target Variable to remove the B'

# %%
df=df_data

# %%
df["class"].nunique()
# Out:
# 2

# %%
df["class"] = df["class"].apply(lambda x: int(x.decode()))

# %%
df["class"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7022    1
# 7023    1
# 7024    1
# 7025    1
# 7026    1
# Name: class, Length: 7027, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Set Figure Size
plt.figure(figsize=(10,6))

# Create the count plot with the 'hue' parameter for legend creation
sns.countplot(data=df, x='class')

# Add a title
plt.title("Count for Target Variable: Bankruptcy")

# Get current handles and labels
labels = ['Successful', 'Bankrupt']

# Set the legend
plt.legend(labels)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Set the figure size
plt.figure(figsize=(10, 6))

# Create the count plot
ax = sns.countplot(data=df, x='class')

# Add a title
plt.title("Count for Target Variable: Bankruptcy")

# Set the x-tick labels
ax.set_xticklabels(['Successful', 'Bankrupt'])

# Annotate the bars with counts
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., 
            p.get_height(), 
            '%d' % int(p.get_height()), 
            fontsize=12, 
            ha='center', 
            va='bottom')
    
    # Create custom legend
successful_patch = mpatches.Patch(color=sns.color_palette()[0], label='Successful (0)')
bankrupt_patch = mpatches.Patch(color=sns.color_palette()[1], label='Bankrupt (1)')
ax.legend(handles=[successful_patch, bankrupt_patch], loc='upper right')

# Display the plot

# Display the plot
plt.show()

# %% [markdown]
# ### Addressing Missing Data

# %%
df2 = df_data

# %%
df2.isnull().sum()
# Out:
# Attr1      3
# Attr2      3
# Attr3      3
# Attr4     30
# Attr5      8
#           ..
# Attr61    22
# Attr62     0
# Attr63    30
# Attr64    34
# class      0
# Length: 65, dtype: int64

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame loaded with data.
# For example:
# df = pd.read_csv("your_data.csv")

columns_with_nan = df2.columns[df2.isna().any()].tolist()

if len(columns_with_nan) > 0:
    # Calculate the proportion of missing values for each column
    plt.figure(figsize=(14, 8)) 
    missing_proportions = df2[columns_with_nan].isna().sum() / len(df)

    # Plot the proportions using a horizontal bar plot
    missing_proportions.plot(kind="barh", title="Proportion of Missing Values by Attributes")
    plt.xlabel('Proportion')
    plt.ylabel('Features')
    plt.tight_layout()
    plt.show()
else:
    print("There are no columns with Missing Values.")

# %%
df2['Attr37'].describe()
# Out:
# count      4287.000000
# mean        173.453694
# std        6339.491580
# min        -525.520000
# 25%           1.296500
# 50%           3.438300
# 75%          11.393500
# max      398920.000000
# Name: Attr37, dtype: float64

# %%
df2['Attr21'].describe()
# Out:
# count     5405.000000
# mean        10.367516
# std        417.358298
# min      -1325.000000
# 25%          1.024400
# 50%          1.137400
# 75%          1.287600
# max      27900.000000
# Name: Attr21, dtype: float64

# %%
df = df.drop(['Attr37', 'Attr21'], axis=1)
df_imputed = df.fillna(df.median())

# %%
df = df_imputed

# %%
display(df)
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %% [markdown]
# ### Duplicate Rows

# %%
num_dupe = df2.duplicated().sum()

print(f"There are {num_dupe} duplicated rows.")
# Out:
# There are 0 duplicated rows.

# %%
df = df.drop_duplicates()
df2=df

# %% [markdown]
# ### Normalize

# %%
# Highest value across the entire dataframe
max_val_all = df.max().max()

# Smallest value across the entire dataframe
min_val_all = df.min().min()

print(f"Highest value in the dataset: {max_val_all}")
print(f"Smallest value in the dataset: {min_val_all}")
# Out:
# Highest value in the dataset: 30393000.0
# Smallest value in the dataset: -5611900.0

# %% [markdown]
# # Random Forest Classification

# %% [markdown]
# ### Grid Search

# %%
#Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold

# Grid Search
X = df.drop("class",axis=1)
y = df['class']


cv = KFold(n_splits=5, shuffle = True, random_state=1)

grid_model = GridSearchCV(estimator=RandomForestClassifier(),
             param_grid={'n_estimators': [20], 
                         'criterion':['gini','entropy'],
                         'max_depth': [5,10,15,20,30,40],
                         'min_samples_split':[16,12,10,8,6],
                         'min_samples_leaf':[6,5,4,3,2],
                        'max_features':[5,10,15,20,30,40]}, cv=cv)


grid_model.fit(X,y)

print('Best max_depth:', grid_model.best_estimator_.get_params()['max_depth'])
print('Best number of trees:', grid_model.best_estimator_.get_params()['n_estimators'])
print('Best Criterion:', grid_model.best_estimator_.get_params()['criterion'])
print('Best Minimum Samples Split:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Minimum Samples Leaf:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Max Features:', grid_model.best_estimator_.get_params()['min_samples_split'])

# %%
print('Best max_depth:', grid_model.best_estimator_.get_params()['max_depth'])
print('Best number of trees:', grid_model.best_estimator_.get_params()['n_estimators'])
print('Best Criterion:', grid_model.best_estimator_.get_params()['criterion'])
print('Best Minimum Samples Split:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Minimum Samples Leaf:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Max Features:', grid_model.best_estimator_.get_params()['max_features'])
# Out:
# Best max_depth: 30
# Best number of trees: 20
# Best Criterion: gini
# Best Minimum Samples Split: 6
# Best Minimum Samples Leaf: 6
# Best Max Features: 30

# %%
#Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold

# Grid Search
X = df.drop("class",axis=1)
y = df['class']


cv = KFold(n_splits=5, shuffle = True, random_state=1)

grid_model = GridSearchCV(estimator=RandomForestClassifier(),
             param_grid={'n_estimators': [20,50,100,150,200], 
                         'criterion':['gini'],
                         'max_depth': [30],
                         'min_samples_split':[6,7,8,9,10],
                         'min_samples_leaf':[6,7,8,9,10],
                        'max_features':[30]}, cv=cv)


grid_model.fit(X,y)

print('Best max_depth:', grid_model.best_estimator_.get_params()['max_depth'])
print('Best number of trees:', grid_model.best_estimator_.get_params()['n_estimators'])
print('Best Criterion:', grid_model.best_estimator_.get_params()['criterion'])
print('Best Minimum Samples Split:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Minimum Samples Leaf:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Max Features:', grid_model.best_estimator_.get_params()['min_samples_split'])
# Out:
# Best max_depth: 30
# Best number of trees: 100
# Best Criterion: gini
# Best Minimum Samples Split: 8
# Best Minimum Samples Leaf: 8
# Best Max Features: 8

# %%
print('Best max_depth:', grid_model.best_estimator_.get_params()['max_depth'])
print('Best number of trees:', grid_model.best_estimator_.get_params()['n_estimators'])
print('Best Criterion:', grid_model.best_estimator_.get_params()['criterion'])
print('Best Minimum Samples Split:', grid_model.best_estimator_.get_params()['min_samples_split'])
print('Best Minimum Samples Leaf:', grid_model.best_estimator_.get_params()['min_samples_leaf'])
print('Best Max Features:', grid_model.best_estimator_.get_params()['max_features'])
# Out:
# Best max_depth: 30
# Best number of trees: 100
# Best Criterion: gini
# Best Minimum Samples Split: 8
# Best Minimum Samples Leaf: 6
# Best Max Features: 30

# %% [markdown]
# ### Fit Random Forest and Get Predictions

# %%
from sklearn.model_selection import train_test_split
# dataset 'df' is now Train/ Test

Train, Test = train_test_split(df, train_size = .7, test_size = .3, random_state=5)

X_train = Train.drop("class",axis=1)
y_train = Train['class']

X_test = Test.drop("class",axis=1)
y_test = Test['class']

# %%
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# Make a decision tree and train
RF = RandomForestClassifier(random_state=5, 
                            max_depth = 30, 
                            n_estimators = 100, 
                            criterion= 'gini',
                            min_samples_split=8,
                            min_samples_leaf=6,max_features=30)
RF_model = RF.fit(X, y)

predsProbs = RF.predict(X)
preds = list(map(round,predsProbs))
actual = y

# %%
from sklearn.model_selection import cross_val_score

# prepare the cross-validation procedure
#cv = KFold(n_splits=5, random_state=1, shuffle=True)
cv = KFold(n_splits=5, shuffle = True, random_state=1)
# create model
model = RandomForestClassifier(random_state=5, 
                            max_depth = 30, 
                            n_estimators = 100, 
                            criterion= 'gini',
                            min_samples_split=8,
                            min_samples_leaf=6,max_features=30)
# evaluate model

scoresAcc = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scoresRec = cross_val_score(model, X, y, scoring='recall', cv=cv, n_jobs=-1)
scoresPrec = cross_val_score(model, X, y, scoring='precision', cv=cv, n_jobs=-1)
scoresF1 = cross_val_score(model, X, y, scoring='f1', cv=cv, n_jobs=-1)
# report performance
print('Accuracy: %.3f (%.3f)' % (np.mean(scoresAcc), np.std(scoresAcc)))
print('Recall: %.3f (%.3f)' % (np.mean(scoresRec), np.std(scoresRec)))
print('Precision: %.3f (%.3f)' % (np.mean(scoresPrec), np.std(scoresPrec)))
print('F1: %.3f (%.3f)' % (np.mean(scoresF1), np.std(scoresF1)))
# Out:
# Accuracy: 0.976 (0.002)
# Recall: 0.376 (0.033)
# Precision: 0.984 (0.032)
# F1: 0.543 (0.033)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from sklearn.metrics import mean_squared_error

from sklearn.metrics import accuracy_score, confusion_matrix

cnf_matrix = confusion_matrix(actual, preds)

labels = [0, 1]

fig, ax = plt.subplots(figsize=(10, 7))

tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels)
plt.yticks(tick_marks, labels)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
ax.xaxis.set_label_position("top")
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual Outcome')
plt.xlabel('Predicted Outcome')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(actual, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6756
#            1       1.00      1.00      1.00       271
#
#     accuracy                           1.00      7027
#    macro avg       1.00      1.00      1.00      7027
# weighted avg       1.00      1.00      1.00      7027

# %%
print("No Informaiton Rate")
print(np.max(np.array([np.mean(df['class']),(1-np.mean(df['class']))])))
# Out:
# No Informaiton Rate
# 0.9614344670556425

# %%
fi = RF.feature_importances_
print(len(fi))
# Out:
# 62

# %%
fi = RF.feature_importances_

FI = pd.DataFrame({"Feature": X.columns, "Importance": np.array(fi)})
FI
sns.barplot(y = "Feature", x = "Importance", data = FI)
plt.show()

# %%
FI_sorted = FI.sort_values(by="Importance", ascending=False)
top_5_FI = FI_sorted.head(10)
fig, ax = plt.subplots(figsize=(10, 7))

sns.barplot(y="Feature", x="Importance", data=top_5_FI)
plt.show()

# %% [markdown]
# ## Extreme Gradient Boosting Machine (XGBoost)

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import numpy as np

# %% [markdown]
# ### Creating the Dataframes

# %%
Train, Test = train_test_split(df, train_size = .7, test_size = .3, random_state=5)
X_train = Train.drop("class",axis=1)
y_train = Train['class']

X_test = Test.drop("class",axis=1)
y_test = Test['class']

# %% [markdown]
# ### Creating XGBoost Object and Fitting

# %%
xgb_model = XGBClassifier()
xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ### Predict the Target Variable using XGB Model

# %%
preds = xgb_model.predict(X_test)
accuracy = xgb_model.score(X_train, y_train)
print(accuracy)
# Out:
# 1.0

# %%
accuracy = xgb_model.score(X, y)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 1.0

# %%
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, preds)

labels = [0, 1]
fig, ax = plt.subplots(figsize=(10, 7))

tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels)
plt.yticks(tick_marks, labels)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
ax.xaxis.set_label_position("top")
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual Outcome')
plt.xlabel('Predicted Outcome')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2026
#            1       0.93      0.45      0.60        83
#
#     accuracy                           0.98      2109
#    macro avg       0.95      0.72      0.79      2109
# weighted avg       0.98      0.98      0.97      2109

# %%
print("No Informaiton Rate")
print(np.max(np.array([np.mean(df["class"]),(1-np.mean(df["class"]))])))
# Out:
# No Informaiton Rate
# 0.9614344670556425

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
predprobs = xgb_model.predict_proba(X_test)

fpr, tpr, thresholds = roc_curve(y_test,  predprobs[:,1])
auc = roc_auc_score(y_test, predprobs[:,1])
print("auc")
print(auc)
# Out:
# auc
# 0.9259089665671572

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

#Optimal Threshhold
print("Optimal Threshold")
print(thresholds[np.argmax(tpr - fpr)])
# Out:
# Optimal Threshold
# 0.0038353645

# %%
#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

#Optimal Threshhold
print("Optimal Threshold")
print(thresholds[np.argmax(tpr - fpr)])
# Out:
# Optimal Threshold
# 0.0038353645

# %% [markdown]
# ### Internal 5-Fold Cross Validation

# %%
# Import Packages
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Prepare Cross-Validation Procedures
cv = KFold(n_splits=5, shuffle=True, random_state=1)

# Create Model
model = XGBClassifier()

# Evaluate Model
X = X_train
y = y_train

scoresAcc = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
scoresRec = cross_val_score(model, X, y, scoring='recall', cv=cv, n_jobs=-1)
scoresPrec = cross_val_score(model, X, y, scoring='precision', cv=cv, n_jobs=-1)
scoresF1 = cross_val_score(model, X, y, scoring='f1', cv=cv, n_jobs=-1)

# Report performance
print('Accuracy: %.3f (%.3f)' % (np.mean(scoresAcc), np.std(scoresAcc)))
print('Recall: %.3f (%.3f)' % (np.mean(scoresRec), np.std(scoresRec)))
print('Precision: %.3f (%.3f)' % (np.mean(scoresPrec), np.std(scoresPrec)))
print('F1: %.3f (%.3f)' % (np.mean(scoresF1), np.std(scoresF1)))
# Out:
# Accuracy: 0.979 (0.005)
# Recall: 0.467 (0.070)
# Precision: 0.960 (0.041)
# F1: 0.624 (0.066)

# %% [markdown]
# ### Grid Search

# %%
#Import Package
from sklearn.model_selection import GridSearchCV

#Parameter Grid
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1, 0.3],
    'n_estimators': [50],
    'max_depth': [3, 4, 5, 6, 7],
    'subsample': [0.8, 0.9, 1],
    'colsample_bytree': [0.8, 0.9, 1],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 3, 5]
}

clf = GridSearchCV(model, param_grid, verbose=1, n_jobs=2, scoring='accuracy')
clf.fit(X_train, y_train)
print("Best parameters found: ", clf.best_params_)
best_model = clf.best_estimator_
# Out:
# Fitting 5 folds for each of 1620 candidates, totalling 8100 fits
# Best parameters found:  {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.3, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 50, 'subsample': 1}

# %%
#Import Package
from sklearn.model_selection import GridSearchCV

#Parameter Grid
param_grid = {
    'learning_rate': [0.3,0.4,0.5],
    'n_estimators': [50,100,150,200,250],
    'max_depth': [6],
    'subsample': [1,1.2,1.5,2],
    'colsample_bytree': [1,1.1,1.5,2],
    'gamma': [0.2,0.3,0.4],
    'min_child_weight': [3]
}

clf = GridSearchCV(model, param_grid, verbose=1, n_jobs=2, scoring='accuracy')
clf.fit(X_train, y_train)
print("Best parameters found: ", clf.best_params_)
best_model = clf.best_estimator_
# Out:
# Fitting 5 folds for each of 720 candidates, totalling 3600 fits
# C:\Users\Vo Nguyen\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 3375 fits failed out of a total of 3600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 225 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Vo Nguyen\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Vo Nguyen\anaconda3\lib\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
# ...
